# %%
import math
print(math.pi)

# %%
import requests
from pprint import pprint

r= requests.get('https://api.github.com/events')
if r.status_code == 200:
    print("下載成功")
    pprint(r.text)
else:
    print("下載失敗")
# Out:
# 下載成功
# ('[{"id":"51913557259","type":"PushEvent","actor":{"id":216030,"login":"juyrjola","display_login":"juyrjola","gravatar_id":"","url":"https://api.github.com/users/juyrjola","avatar_url":"https://avatars.githubusercontent.com/u/216030?"},"repo":{"id":287305233,"name":"kausaltech/dvctest","url":"https://api.github.com/repos/kausaltech/dvctest"},"payload":{"repository_id":287305233,"push_id":25407861452,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"68a41026102d0445070298a2772f2c7b1691ace1","before":"86d7238063895c191b57eaf3a9d155de0ccef5c0","commits":[{"sha":"68a41026102d0445070298a2772f2c7b1691ace1","author":{"email":"mike.mechenich@gmail.com","name":"Michael '
#  'Mechenich"},"message":"Update '
# ...
