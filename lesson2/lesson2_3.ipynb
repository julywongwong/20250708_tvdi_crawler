# %%
import math
print(math.pi)

# %%
import requests
from pprint import pprint

r= requests.get('https://api.github.com/events')
pprint(r.text)
# Out:
# ('[{"id":"51910945731","type":"PushEvent","actor":{"id":142812153,"login":"AryanJ2004","display_login":"AryanJ2004","gravatar_id":"","url":"https://api.github.com/users/AryanJ2004","avatar_url":"https://avatars.githubusercontent.com/u/142812153?"},"repo":{"id":814493242,"name":"AryanJ2004/LEETCODE-DAILY-CODE-CHALLANGE","url":"https://api.github.com/repos/AryanJ2004/LEETCODE-DAILY-CODE-CHALLANGE"},"payload":{"repository_id":814493242,"push_id":25406609401,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"a5c7ac1cf750108088bd4f44a5b44172e770bc14","before":"bdb06ae1f4c520c175de652e721b091b15af2c84","commits":[{"sha":"a5c7ac1cf750108088bd4f44a5b44172e770bc14","author":{"email":"aryanj1084@gmail.com","name":"Aryan '
#  'Jain"},"message":"Time: 0 ms (100%), Space: 10.8 MB (70.17%) - '
# ...
